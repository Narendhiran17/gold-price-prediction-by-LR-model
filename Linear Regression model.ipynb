# %%
#libraries
import yfinance as yf
import seaborn as sb

# %%
#data colllection
u_i = yf.download("USDINR=X", start='2024-01-01', end='2024-12-31', interval='1wk')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
type(u_i)
# Out:
# pandas.core.frame.DataFrame

# %%
u_i.head()
# Out:
# Price           Close       High        Low       Open   Volume
# Ticker       USDINR=X   USDINR=X   USDINR=X   USDINR=X USDINR=X
# Date
# 2024-01-01  83.240601  83.360298  83.035004  83.248596        0
# 2024-01-08  83.076103  83.189697  82.779099  83.191101        0
# 2024-01-15  83.160599  83.230797  82.809998  82.872101        0
# 2024-01-22  83.146103  83.222504  81.513702  83.124702        0
# 2024-01-29  82.927597  83.212601  82.815002  83.121300        0

# %%
u_i.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 53 entries, 2024-01-01 to 2024-12-30
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Close, USDINR=X)   53 non-null     float64
#  1   (High, USDINR=X)    53 non-null     float64
#  2   (Low, USDINR=X)     53 non-null     float64
#  3   (Open, USDINR=X)    53 non-null     float64
#  4   (Volume, USDINR=X)  53 non-null     int64
# dtypes: float64(4), int64(1)
# memory usage: 2.5 KB

# %%
u_i.reset_index(inplace=True)

# %%
u_i.head()
# Out:
# Price        Date      Close       High        Low       Open   Volume
# Ticker              USDINR=X   USDINR=X   USDINR=X   USDINR=X USDINR=X
# 0      2024-01-01  83.240601  83.360298  83.035004  83.248596        0
# 1      2024-01-08  83.076103  83.189697  82.779099  83.191101        0
# 2      2024-01-15  83.160599  83.230797  82.809998  82.872101        0
# 3      2024-01-22  83.146103  83.222504  81.513702  83.124702        0
# 4      2024-01-29  82.927597  83.212601  82.815002  83.121300        0

# %%
# trim the DF for desired data
u_i = u_i[['Date','Close']]
u_i.columns = ['Date','USD-INR']

# %%
u_i.head()
# Out:
#         Date    USD-INR
# 0 2024-01-01  83.240601
# 1 2024-01-08  83.076103
# 2 2024-01-15  83.160599
# 3 2024-01-22  83.146103
# 4 2024-01-29  82.927597

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

gold = pd.read_csv("Gold vs USDINR.csv")
gold["Goldrate"] = gold["Goldrate"]. replace(",",'', regex=True,).replace("₹",'', regex=True). astype(float)

gold.head()
# Out:
#          Date    USD_INR  Goldrate
# 0  2024-01-01  83.240601   5066.31
# 1  2024-01-08  83.076103   4966.31
# 2  2024-01-15  83.160599   5015.33
# 3  2024-01-22  83.146103   4950.84
# 4  2024-01-29  82.927597   4976.77

# %%
gold.dropna()
# Out:
#           Date    USD_INR  Goldrate
# 0   2024-01-01  83.240601   5066.31
# 1   2024-01-08  83.076103   4966.31
# 2   2024-01-15  83.160599   5015.33
# 3   2024-01-22  83.146103   4950.84
# 4   2024-01-29  82.927597   4976.77
# 5   2024-02-05  82.985298   4953.90
# 6   2024-02-12  83.009598   4938.73
# 7   2024-02-19  82.872299   4934.99
# 8   2024-02-26  82.910400   4960.54
# 9   2024-03-04  82.752296   5167.64
# 10  2024-03-11  82.965599   5326.46
# 11  2024-03-18  83.226601   5283.44
# 12  2024-03-25  83.392998   5341.21
# 13  2024-04-01  83.477798   5543.85
# 14  2024-04-08  83.349297   5737.21
# 15  2024-04-15  83.544998   5874.86
# 16  2024-04-22  83.301804   5720.10
# 17  2024-04-29  83.406303   5744.34
# 18  2024-05-06  83.459396   5724.77
# 19  2024-05-13  83.470100   5754.39
# 20  2024-05-20  83.286400   5966.34
# 21  2024-05-27  83.320900   5765.04
# 22  2024-06-03  83.473099   5757.16
# 23  2024-06-10  83.522102   5691.70
# 24  2024-06-17  83.601601   5710.88
# ...

# %%
gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      53 non-null     object
#  1   USD_INR   53 non-null     float64
#  2   Goldrate  53 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.4+ KB

# %%
gold.head()
# Out:
#          Date    USD_INR  Goldrate
# 0  2024-01-01  83.240601   5066.31
# 1  2024-01-08  83.076103   4966.31
# 2  2024-01-15  83.160599   5015.33
# 3  2024-01-22  83.146103   4950.84
# 4  2024-01-29  82.927597   4976.77

# %%
#EDA
 #handle missing values - no
 #handle imbalanced dataset - no
 #handle outliers - 2
 #encode categorical features - numerical features
 #normalization vs standardization -

# %%
gold["USD_INR"].plot(kind = "box")
# Out:
# <Axes: >

# %%
gold["USD_INR"].max()
# Out:
# np.float64(85.78659821)

# %%
gold["USD_INR"].min()
# Out:
# np.float64(82.75229645)

# %%
#modelling
#independent variable
x =gold[["USD_INR"]]
y = gold[["Goldrate"]]

# %%
type(x) # in this type DF is more usefull for future things
# Out:
# pandas.core.frame.DataFrame

# %%
x.shape, y.shape
# Out:
# ((53, 1), (53, 1))

# %%
# data split for train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=33)

# %%
x_train.shape, x_test.shape
# Out:
# ((47, 1), (6, 1))

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train_scaled_values = scaler.fit_transform(x_train)
x_test_scaled_values = scaler.transform(x_test)

# %%
x_test_scaled_values.shape
# Out:
# (6, 1)

# %%
x_test_scaled_values
# Out:
# array([[ 1.17014699],
#        [ 0.45888396],
#        [-0.97052451],
#        [-0.14562532],
#        [ 0.05224764],
#        [ 0.05301885]])

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train_scaled_values, y_train)
# Out:
# LinearRegression()

# %%
lr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
lr.coef_[0][0]
# Out:
# np.float64(488.13558475612825)

# %%
lr.intercept_[0]
# Out:
# np.float64(5873.422127659569)

# %%
# y = mx+b
m = lr.coef_[0][0]
b = lr.intercept_[0]

# %%
m,b
# Out:
# (np.float64(488.13558475612825), np.float64(5873.422127659569))

# %%
x_train_predict = lr.predict(x_train_scaled_values)

# %%
import matplotlib.pyplot as mt

mt.scatter(x_train, y_train)
mt.plot(x_train, x_train_predict, color="r")
mt.xlabel("USD-INR")
mt.ylabel("Goldrate")

mt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x_test_predict = lr.predict(x_test_scaled_values)
x_test_predict
# Out:
# array([[6444.61251398],
#        [6097.41972016],
#        [5399.67458029],
#        [5802.33722464],
#        [5898.9260597 ],
#        [5899.30251317]])

# %%
y_test
# Out:
#     Goldrate
# 45   6523.10
# 39   6507.66
# 1    4966.31
# 37   6384.57
# 30   5883.33
# 29   5909.38

# %%
#hyperparameter optimization
from sklearn.model_selection import RandomizedSearchCV
param = {'copy_X': [True,False],
         'fit_intercept': [True,False],
         'n_jobs': [1,5,10,15,None],
         'positive': [True,False]}

# %%
var = RandomizedSearchCV(lr, param, n_iter=40, cv=10)
var.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=10, estimator=LinearRegression(), n_iter=40,
#                    param_distributions={'copy_X': [True, False],
#                                         'fit_intercept': [True, False],
#                                         'n_jobs': [1, 5, 10, 15, None],
#                                         'positive': [True, False]})

# %%
var.best_params_
# Out:
# {'positive': True, 'n_jobs': 1, 'fit_intercept': True, 'copy_X': True}

# %%
lr2 = LinearRegression(positive= True, n_jobs= 1, fit_intercept= True, copy_X= True)

# %%
lr2.fit(x_train_scaled_values, y_train)
# Out:
# LinearRegression(n_jobs=1, positive=True)

# %%
lr2.coef_
# Out:
# array([[488.13558476]])

# %%
lr2.intercept_
# Out:
# array([5873.42212766])

# %%
#MLOOPPS
 # SAVE THE MODEL
 # BUILD INTERFACE
 # CONNECT MODEL & INTERFACE

# %%
import pickle

# %%
pickle.dump(lr2, open("lr2.pkl", "wb"))
o = pickle.load(open("lr2.pkl", "rb"))
o.coef_
# Out:
# array([[488.13558476]])

# %%
pickle.dump(scaler, open("scaler.pkl", "wb"))

# %%
#function for our model

def gold_price(USD_INR):
    scale = scaler.transform(np.array(USD_INR), reshape(-1,1))
    return lr2.predict(scale)

# %%
import gradio as gr

def gold_price(USD_INR):
    scale = scaler.transform(np.array(USD_INR).reshape(-1,1))
    return lr2.predict(scale)[0][0].round(2)

demo = gr.Interface(
    fn= gold_price,
    inputs=["number"],
    outputs=["number"],
    title = "How much is 1Gram in India NOW?"
)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7874
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7874/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# C:\Users\naren\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\naren\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\naren\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
